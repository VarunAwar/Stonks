# %%
import yfinance as yf
import pandas as pd
import numpy as np
import yahoo_finance as yhoo
import matplotlib.pyplot as plt
from yahoo_finance import Share
import csv
import datetime
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
import time
import datetime
import os
from IPython.display import clear_output
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def name_of_company(ticker):
    """
    This function returns the long name of the company
    """
    print("Name: ",yf.Ticker(ticker).info['longName'])

# %%
def avg_rev(ticker):
    """
    This Function provides the average Revenue of the company
    """
    print("The average revenue of",ticker,"is $",yf.Ticker(ticker).calendar.loc['Revenue Average'][0],"on",yf.Ticker(ticker).calendar.loc['Earnings Date'][0])

# %%
def social_score(ticker):
    """
    This function provides the social score of the company
    """
    df = yf.Ticker(ticker).sustainability.loc['socialScore']
    print("The social score of {} is {}".format(yf.Ticker(ticker).info['longName'],df))

# %%
def env_score(ticker):
    """
    This function provides the environmental score of the company
    """
    df = yf.Ticker(ticker).sustainability.loc['environmentScore']
    print("The Environmental score of {} is {}".format(yf.Ticker(ticker).info['longName'],df))

# %%
def dividend(ticker):
    '''
    This function returns Dividends provided by the company over the years-[if provided].
    '''
    if yf.Ticker(ticker).dividends.empty:
        print("The Company never offered Dividend to its stake holders")
    else:
        divi = pd.DataFrame(yf.Ticker(ticker).dividends)
        return divi
# dividend('AAPL')

# %%
def shareholders(ticker):
    """
    This function provides the top 5 institutional holders
    """
    return yf.Ticker(ticker).get_institutional_holders().head().drop('Date Reported',axis=1)
# shareholders("AAPL")

# %%
def cur_price(ticker):
    """
    This provides the current market price of the stock. It has a minor lag
    """
    while True:
        now = datetime.datetime.now()
        time1 = now.strftime("%H:%M:%S")
        tickers = yf.Ticker(ticker)
        todays_data = tickers.history(period='1d')
        print(time1,"-",todays_data['Close'][0])
        time.sleep(5)
        clear_output(wait=True)

# %%
def graph_open_close(ticker):
    """
    This graph provides the graph of opening and closing prices
    """
    print("Enter the Period(in months):")
    period = input()
    yf.Ticker(ticker).history(period='{}mo'.format(period))[['Open','Close']].iplot()
# graph_open_close("AAPL")

# %%
def open_price(ticker):
    """
    This function provides the opening price
    """
    df= yf.Ticker(ticker).info['open']
    print("Opening price: ",df)

# %%
def last_close(ticker):
    """
    This function provides the last closing price
    """
    df= yf.Ticker(ticker).info['previousClose']
    print("Previous Closing price: ",df)

# %%
def fifty_two(ticker):
    print("52 week high:",yf.Ticker(ticker).info['fiftyTwoWeekHigh'])
    print("52 week low:",yf.Ticker(ticker).info['fiftyTwoWeekLow'])
    print("52 week change:",yf.Ticker(ticker).info['52WeekChange'],"%")
    
# fifty_two('RELIANCE.NS')

# %%
def market_cap(ticker):
    """
    This function provides the total value of all the shares of the company
    """
    vol = yf.Ticker(ticker).info['volume']
    price = yf.Ticker(ticker).history(period='1d')['Close'][0]
    mark_cap = vol*price
    name = yf.Ticker(ticker).info['longName']
    print("The total market cap of {} is {}".format(name,mark_cap))
# market_cap('AAPL')

# %%
def main_func(ticker):
    ticker = ticker.capitalize()
    name_of_company(ticker)
    social_score(ticker)
    env_score(ticker)
    fifty_two(ticker)
    avg_rev(ticker)
    x = dividend(ticker)
    y = shareholders(ticker)
    open_price(ticker)
    last_close(ticker)
#     return pd.DataFrame(x).tail()
    return pd.DataFrame(y)

# %%
main_func('SBIN.NS')
# Out:
# Name:  State Bank of India
# The social score of State Bank of India is Value    13.09
# Name: socialScore, dtype: object
# The Environmental score of State Bank of India is Value    2.33
# Name: environmentScore, dtype: object
# 52 week high: 427.7
# 52 week low: 149.45
# 52 week change: 0.34075904 %
# The average revenue of Sbin.ns is $ 302650000000 on 2021-02-04 00:00:00
# Opening price:  399.5
# Previous Closing price:  407.25
#                                               Holder    Shares   % Out  \
# 0  Vanguard International Stock Index-Total Intl ...  22914847  0.0026
# 1  Vanguard International Stock Index-Emerging Ma...  17222777  0.0019
# 2             iShares Core MSCI Emerging Markets ETF  14882391  0.0017
# 3                             iShares MSCI India ETF  11904750  0.0013
# 4  DFA Investment Dimensions-DFA Emerging Mkts Value   7108564  0.0008
#
#         Value
# 0  4336634794
# 1  3259410547
# 2  4091913405
# 3  3273211012
# 4  1345295737

# %%
graph_open_close("SBIN.NS")
# Out:
# Enter the Period(in months):
# 60
# <div>                            <div id="80fb0ba1-7441-4977-8172-7dbd5bf66524" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("80fb0ba1-7441-4977-8172-7dbd5bf66524")) {                    Plotly.newPlot(                        "80fb0ba1-7441-4977-8172-7dbd5bf66524",                        [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Open", "text": "", "type": "scatter", "x": ["2016-02-26", "2016-02-29", "2016-03-01", "2016-03-02", "2016-03-03", "2016-03-04", "2016-03-08", "2016-03-09", "2016-03-10", "2016-03-11", "2016-03-14", "2016-03-15", "2016-03-16", "2016-03-17", "2016-03-18", "2016-03-21", "2016-03-22", "2016-03-23", "2016-03-28", "2016-03-29", "2016-03-30", "2016-03-31", "2016-04-01", "2016-04-04", "2016-04-05", "2016-04-06", "2016-04-07", "2016-04-08", "2016-04-11", "2016-04-12", "2016-04-13", "2016-04-18", "2016-04-20", "2016-04-21", "2016-04-22", "2016-04-25", "2016-04-26", "2016-04-27", "2016-04-28", "2016-04-29", "2016-05-02", "2016-05-03", "2016-05-04", "2016-05-05", "2016-05-06", "2016-05-09", "2016-05-10", "2016-05-11", "2016-05-12", "2016-05-13", "2016-05-16", "2016-05-17", "2016-05-18", "2016-05-19", "2016-05-20", "2016-05-23", "2016-05-24", "2016-05-25", "2016-05-26", "2016-05-27", "2016-05-30", "2016-05-31", "2016-06-01", "2016-06-02", "2016-06-03", "2016-06-06", "2016-06-07", "2016-06-08", "2016-06-09", "2016-06-10", "2016-06-13", "2016-06-14", "2016-06-15", "2016-06-16", "2016-06-17", "2016-06-20", "2016-06-21", "2016-06-22", "2016-06-23", "2016-06-24", "2016-06-27", "2016-06-28", "2016-06-29", "2016-06-30", "2016-07-01", "2016-07-04", "2016-07-05", "2016-07-07", "2016-07-08", "2016-07-11", "2016-07-12", "2016-07-13", "2016-07-14", "2016-07-15", "2016-07-18", "2016-07-19", "2016-07-20", "2016-07-21", "2016-07-22", "2016-07-25", "2016-07-26", "2016-07-27", "2016-07-28", "2016-07-29", "2016-08-01", "2016-08-02", "2016-08-03", "2016-08-04", "2016-08-05", "2016-08-08", "2016-08-09", "2016-08-10", "2016-08-11", "2016-08-12", "2016-08-16", "2016-08-17", "2016-08-18", "2016-08-19", "2016-08-22", "2016-08-23", "2016-08-24", "2016-08-25", "2016-08-26", "2016-08-29", "2016-08-30", "2016-08-31", "2016-09-01", "2016-09-02", "2016-09-06", "2016-09-07", "2016-09-08", "2016-09-09", "2016-09-12", "2016-09-14", "2016-09-15", "2016-09-16", "2016-09-19", "2016-09-20", "2016-09-21", "2016-09-22", "2016-09-23", "2016-09-26", "2016-09-27", "2016-09-28", "2016-09-29", "2016-09-30", "2016-10-03", "2016-10-04", "2016-10-05", "2016-10-06", "2016-10-07", "2016-10-10", "2016-10-13", "2016-10-14", "2016-10-17", "2016-10-18", "2016-10-19", "2016-10-20", "2016-10-21", "2016-10-24", "2016-10-25", "2016-10-26", "2016-10-27", "2016-10-28", "2016-11-01", "2016-11-02", "2016-11-03", "2016-11-04", "2016-11-07", "2016-11-08", "2016-11-09", "2016-11-10", "2016-11-11", "2016-11-15", "2016-11-16", "2016-11-17", "2016-11-18", "2016-11-21", "2016-11-22", "2016-11-23", "2016-11-24", "2016-11-25", "2016-11-28", "2016-11-29", "2016-11-30", "2016-12-01", "2016-12-02", "2016-12-05", "2016-12-06", "2016-12-07", "2016-12-08", "2016-12-09", "2016-12-12", "2016-12-13", "2016-12-14", "2016-12-15", "2016-12-16", "2016-12-19", "2016-12-20", "2016-12-21", "2016-12-22", "2016-12-23", "2016-12-26", "2016-12-27", "2016-12-28", "2016-12-29", "2016-12-30", "2017-01-02", "2017-01-03", "2017-01-04", "2017-01-05", "2017-01-06", "2017-01-09", "2017-01-10", "2017-01-11", "2017-01-12", "2017-01-13", "2017-01-16", "2017-01-17", "2017-01-18", "2017-01-19", "2017-01-20", "2017-01-23", "2017-01-24", "2017-01-25", "2017-01-27", "2017-01-30", "2017-01-31", "2017-02-01", "2017-02-02", "2017-02-03", "2017-02-06", "2017-02-07", "2017-02-08", "2017-02-09", "2017-02-10", "2017-02-13", "2017-02-14", "2017-02-15", "2017-02-16", "2017-02-17", "2017-02-20", "2017-02-21", "2017-02-22", "2017-02-23", "2017-02-27", "2017-02-28", "2017-03-01", "2017-03-02", "2017-03-03", "2017-03-06", "2017-03-07", "2017-03-08" ...

# %%
cur_price('SBIN.NS')
# Out:
# 14:56:49 - 393.6
